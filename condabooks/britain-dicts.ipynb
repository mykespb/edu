# %% [markdown]
# ***britain.ipynb***
#
# *2024-11-29 2024-12-03 1.3 Mikhail Kolodin*
#
# **С помощью множеств, словарей и т.п. описать структуру всего британского и провести над ними действия.**
#
# ***Тема: словари.***

# %%
from pprint import pp

# %% [markdown]
# **Шаг 0. Готовим исходные данные.**

# %%
data="""name	code	official	territory	population	capital	languages	world	currency	EU	Shengen	Commonwealth	Realm	NATO	power	driveson	wiki
England	england	England	132932	57106398	London	English	Europe	GBP	no	no	yes	yes	yes	monarchy	left	https://en.wikipedia.org/wiki/England 
Wales	wales	Wales	21218	3131640	Cardiff	English, Welsh	Europe	GBP	no	no	yes	yes	yes	monarchy	left	https://en.wikipedia.org/wiki/Wales
Scotland	scotland	Scotland	80231	5439842	Edinburgh	English, Scots, Scortish Gaelic, British Sign	Europe	GBP	no	no	yes	yes	yes	monarchy	left	https://en.wikipedia.org/wiki/Scotland
Nothern Ireland	n_ireland	Nothern Ireland	14330	1910543	Belfast	English, Irish	Europe	GBP	no	no	yes	yes	yes	monarchy	left	https://en.wikipedia.org/wiki/Northern_Ireland
Isle of Man	ioman	Isle of Man	574	84069	Douglas	English, Manx	Europe	GBP, IMP	no	no	yes	yes	no	monarchy	left	https://en.wikipedia.org/wiki/Isle_of_Man
Jersey	bei_jersey	Bailiwick of Jersey	120	103267	St.Helier	English, French, Jerriais	Europe	GBP, JEP	no	no	yes	yes	no	monarchy	left	https://en.wikipedia.org/wiki/Jersey
Guernsey	bei_guernsey	Bailiwick of Guernsey	78	67334	St.Peter Port	English, French, Sercquiais, Auregnais	Europe	GBP, GGP	no	no	yes	yes	no	monarchy	left	https://en.wikipedia.org/wiki/Bailiwick_of_Guernsey
Ireland	rep_ireland	Ireland	244376	68265209	Dublin	English, Irish	Europe	EUR	yes	yes	no	no	yes	republic	left	https://en.wikipedia.org/wiki/Ireland
Great Britain	britain	Great Britain	209331	65685738	London	English	Europe	GBP	no	no	yes	yes	yes	monarchy	left	https://en.wikipedia.org/wiki/Great_Britain
United Kingdom	uk	United Kingdom of Great Britain and Northern Ireland	244376	68265209	London	English, Scots, Ulster, Scots, Welsh, Cornish, Scottish, Gaelic, Irish, British Sign Language	Europe	GBP	no	no	yes	yes	yes	monarchy	left	https://en.wikipedia.org/wiki/United_Kingdom
overseas	overseas	British Overseas Territories	1727415	272256	London	English	World	GBP	no	no	yes	yes	yes	monarchy	left	https://en.wikipedia.org/wiki/British_Overseas_Territories
Antigua and Barbuda	antigua	Antigua and Barbuda	440000	100772	St. John's	English, Antiguan and Barbudan Creole	Central America	XCD	no	no	yes	yes	no	monarchy	left	https://en.wikipedia.org/wiki/Antigua_and_Barbuda
Australia	australia	Australia	7688287	27536000	Canberra	English	Australia	AUD	no	no	yes	yes	no	monarchy	left	https://en.wikipedia.org/wiki/Australia
Bahamas	bahamas	Commonwealth of The Bahamas	13943	412628	Nassau	English, Bahamian Creole	Central America	BSD, USD	no	no	yes	yes	no	monarchy	left	https://en.wikipedia.org/wiki/The_Bahamas
Belize	belize	Belize	22966	397483	Belize City	English, Belizean Creole	Central America	BZD	no	no	yes	yes	no	monarchy	left	https://en.wikipedia.org/wiki/Belize
Canada	canada	Canada	9984670	41288599	Ottawa	English, French	North America	CAD	no	no	yes	yes	yes	monarchy	left	https://en.wikipedia.org/wiki/Canada
Grenada	grenada	Grenada	349	124610	St. George's	English, Grenadian Creole English, Grenadian Creole French	Central America	XCD	no	no	yes	yes	no	monarchy	left	https://en.wikipedia.org/wiki/Grenada
Jamaica	jamaica	Jamaica	10991	2734092	Kingston	English, Jamaican Patois	Central America	JMD	no	no	yes	yes	no	monarchy	left	https://en.wikipedia.org/wiki/Jamaica
New Zealand	nzeland	New Zealand	268021	5432170	Wellington	English, Māori, NZ Sign Language	Australia	NZD	no	no	yes	yes	yes	monarchy	left	https://en.wikipedia.org/wiki/New_Zealand
Papua New Guinea	papua	Papua New Guinea	462840	11781559	Port Moresby	English, Hiri Motu, PNG Sign Language, Tok Pisin	Oceania	PGK	no	no	yes	yes	yes	monarchy	left	https://en.wikipedia.org/wiki/Papua_New_Guinea
Saint Kitts and Nevis	skn	Federation of Saint Christopher and Nevis	261	47606	Basseterre	English, Saint Kitts Creole	Central America	XCD	no	no	yes	yes	no	monarchy	left	https://en.wikipedia.org/wiki/Saint_Kitts_and_Nevis
Saint Lucia	stlucia	Saint Lucia	617	178696	Castries	English, Saint Lucian Creole, French	Central America	XCD	no	no	yes	yes	no	monarchy	left	https://en.wikipedia.org/wiki/Saint_Lucia
Saint Vincent and the Grenadines	vincent	Saint Vincent and the Grenadines	389	110872	Kingstown	English, Vincentian Creole	Central America	XCD	no	no	yes	yes	no	monarchy	left	https://en.wikipedia.org/wiki/Saint_Vincent_and_the_Grenadines
Solomon Islands 	solomons	Solomon Islands 	28896	734887	Honiara	English, Pijin	Oceania	XCD	no	no	yes	yes	no	monarchy	left	https://en.wikipedia.org/wiki/Solomon_Islands
Tuvalu	tuvalu	Tuvalu	26	11900	Funafuti	Tuvaluan, English	Oceania	AUD, TD	no	no	yes	yes	no	monarchy	left	https://en.wikipedia.org/wiki/Tuvalu"""

# %%
print(data)
# Out:
# name	code	official	territory	population	capital	languages	world	currency	EU	Shengen	Commonwealth	Realm	NATO	power	driveson	wiki
# England	england	England	132932	57106398	London	English	Europe	GBP	no	no	yes	yes	yes	monarchy	left	https://en.wikipedia.org/wiki/England
# Wales	wales	Wales	21218	3131640	Cardiff	English, Welsh	Europe	GBP	no	no	yes	yes	yes	monarchy	left	https://en.wikipedia.org/wiki/Wales
# Scotland	scotland	Scotland	80231	5439842	Edinburgh	English, Scots, Scortish Gaelic, British Sign	Europe	GBP	no	no	yes	yes	yes	monarchy	left	https://en.wikipedia.org/wiki/Scotland
# Nothern Ireland	n_ireland	Nothern Ireland	14330	1910543	Belfast	English, Irish	Europe	GBP	no	no	yes	yes	yes	monarchy	left	https://en.wikipedia.org/wiki/Northern_Ireland
# Isle of Man	ioman	Isle of Man	574	84069	Douglas	English, Manx	Europe	GBP, IMP	no	no	yes	yes	no	monarchy	left	https://en.wikipedia.org/wiki/Isle_of_Man
# Jersey	bei_jersey	Bailiwick of Jersey	120	103267	St.Helier	English, French, Jerriais	Europe	GBP, JEP	no	no	yes	yes	no	monarchy	left	https://en.wikipedia.org/wiki/Jersey
# Guernsey	bei_guernsey	Bailiwick of Guernsey	78	67334	St.Peter Port	English, French, Sercquiais, Auregnais	Europe	GBP, GGP	no	no	yes	yes	no	monarchy	left	https://en.wikipedia.org/wiki/Bailiwick_of_Guernsey
# Ireland	rep_ireland	Ireland	244376	68265209	Dublin	English, Irish	Europe	EUR	yes	yes	no	no	yes	republic	left	https://en.wikipedia.org/wiki/Ireland
# Great Britain	britain	Great Britain	209331	65685738	London	English	Europe	GBP	no	no	yes	yes	yes	monarchy	left	https://en.wikipedia.org/wiki/Great_Britain
# United Kingdom	uk	United Kingdom of Great Britain and Northern Ireland	244376	68265209	London	English, Scots, Ulster, Scots, Welsh, Cornish, Scottish, Gaelic, Irish, British Sign Language	Europe	GBP	no	no	yes	yes	yes	monarchy	left	https://en.wikipedia.org/wiki/United_Kingdom
# overseas	overseas	British Overseas Territories	1727415	272256	London	English	World	GBP	no	no	yes	yes	yes	monarchy	left	https://en.wikipedia.org/wiki/British_Overseas_Territories
# Antigua and Barbuda	antigua	Antigua and Barbuda	440000	100772	St. John's	English, Antiguan and Barbudan Creole	Central America	XCD	no	no	yes	yes	no	monarchy	left	https://en.wikipedia.org/wiki/Antigua_and_Barbuda
# Australia	australia	Australia	7688287	27536000	Canberra	English	Australia	AUD	no	no	yes	yes	no	monarchy	left	https://en.wikipedia.org/wiki/Australia
# Bahamas	bahamas	Commonwealth of The Bahamas	13943	412628	Nassau	English, Bahamian Creole	Central America	BSD, USD	no	no	yes	yes	no	monarchy	left	https://en.wikipedia.org/wiki/The_Bahamas
# Belize	belize	Belize	22966	397483	Belize City	English, Belizean Creole	Central America	BZD	no	no	yes	yes	no	monarchy	left	https://en.wikipedia.org/wiki/Belize
# Canada	canada	Canada	9984670	41288599	Ottawa	English, French	North America	CAD	no	no	yes	yes	yes	monarchy	left	https://en.wikipedia.org/wiki/Canada
# Grenada	grenada	Grenada	349	124610	St. George's	English, Grenadian Creole English, Grenadian Creole French	Central America	XCD	no	no	yes	yes	no	monarchy	left	https://en.wikipedia.org/wiki/Grenada
# Jamaica	jamaica	Jamaica	10991	2734092	Kingston	English, Jamaican Patois	Central America	JMD	no	no	yes	yes	no	monarchy	left	https://en.wikipedia.org/wiki/Jamaica
# New Zealand	nzeland	New Zealand	268021	5432170	Wellington	English, Māori, NZ Sign Language	Australia	NZD	no	no	yes	yes	yes	monarchy	left	https://en.wikipedia.org/wiki/New_Zealand
# Papua New Guinea	papua	Papua New Guinea	462840	11781559	Port Moresby	English, Hiri Motu, PNG Sign Language, Tok Pisin	Oceania	PGK	no	no	yes	yes	yes	monarchy	left	https://en.wikipedia.org/wiki/Papua_New_Guinea
# Saint Kitts and Nevis	skn	Federation of Saint Christopher and Nevis	261	47606	Basseterre	English, Saint Kitts Creole	Central America	XCD	no	no	yes	yes	no	monarchy	left	https://en.wikipedia.org/wiki/Saint_Kitts_and_Nevis
# Saint Lucia	stlucia	Saint Lucia	617	178696	Castries	English, Saint Lucian Creole, French	Central America	XCD	no	no	yes	yes	no	monarchy	left	https://en.wikipedia.org/wiki/Saint_Lucia
# Saint Vincent and the Grenadines	vincent	Saint Vincent and the Grenadines	389	110872	Kingstown	English, Vincentian Creole	Central America	XCD	no	no	yes	yes	no	monarchy	left	https://en.wikipedia.org/wiki/Saint_Vincent_and_the_Grenadines
# Solomon Islands 	solomons	Solomon Islands 	28896	734887	Honiara	English, Pijin	Oceania	XCD	no	no	yes	yes	no	monarchy	left	https://en.wikipedia.org/wiki/Solomon_Islands
# Tuvalu	tuvalu	Tuvalu	26	11900	Funafuti	Tuvaluan, English	Oceania	AUD, TD	no	no	yes	yes	no	monarchy	left	https://en.wikipedia.org/wiki/Tuvalu

# %% [markdown]
# **Шаг 1. Прочитать данные в список**

# %%
states = data.strip().split("\n")

pp(states)
# Out:
# ['name\tcode\tofficial\tterritory\tpopulation\tcapital\tlanguages\tworld\t'
#  'currency\tEU\tShengen\tCommonwealth\tRealm\tNATO\tpower\tdriveson\twiki',
#  'England\tengland\tEngland\t132932\t57106398\tLondon\tEnglish\tEurope\tGBP\t'
#  'no\tno\tyes\tyes\tyes\tmonarchy\tleft\t'
#  'https://en.wikipedia.org/wiki/England ',
#  'Wales\twales\tWales\t21218\t3131640\tCardiff\tEnglish, Welsh\tEurope\tGBP\t'
#  'no\tno\tyes\tyes\tyes\tmonarchy\tleft\thttps://en.wikipedia.org/wiki/Wales',
#  'Scotland\tscotland\tScotland\t80231\t5439842\tEdinburgh\tEnglish, Scots, '
#  'Scortish Gaelic, British Sign\tEurope\tGBP\tno\tno\tyes\tyes\tyes\tmonarchy\t'
#  'left\thttps://en.wikipedia.org/wiki/Scotland',
#  'Nothern Ireland\tn_ireland\tNothern Ireland\t14330\t1910543\tBelfast\t'
#  'English, Irish\tEurope\tGBP\tno\tno\tyes\tyes\tyes\tmonarchy\tleft\t'
#  'https://en.wikipedia.org/wiki/Northern_Ireland',
#  'Isle of Man\tioman\tIsle of Man\t574\t84069\tDouglas\tEnglish, Manx\tEurope\t'
#  'GBP, IMP\tno\tno\tyes\tyes\tno\tmonarchy\tleft\t'
#  'https://en.wikipedia.org/wiki/Isle_of_Man',
#  'Jersey\tbei_jersey\tBailiwick of Jersey\t120\t103267\tSt.Helier\tEnglish, '
#  'French, Jerriais\tEurope\tGBP, JEP\tno\tno\tyes\tyes\tno\tmonarchy\tleft\t'
#  'https://en.wikipedia.org/wiki/Jersey',
#  'Guernsey\tbei_guernsey\tBailiwick of Guernsey\t78\t67334\tSt.Peter Port\t'
#  'English, French, Sercquiais, Auregnais\tEurope\tGBP, GGP\tno\tno\tyes\tyes\t'
#  'no\tmonarchy\tleft\thttps://en.wikipedia.org/wiki/Bailiwick_of_Guernsey',
#  'Ireland\trep_ireland\tIreland\t244376\t68265209\tDublin\tEnglish, Irish\t'
#  'Europe\tEUR\tyes\tyes\tno\tno\tyes\trepublic\tleft\t'
#  'https://en.wikipedia.org/wiki/Ireland',
#  'Great Britain\tbritain\tGreat Britain\t209331\t65685738\tLondon\tEnglish\t'
#  'Europe\tGBP\tno\tno\tyes\tyes\tyes\tmonarchy\tleft\t'
#  'https://en.wikipedia.org/wiki/Great_Britain',
#  'United Kingdom\tuk\tUnited Kingdom of Great Britain and Northern Ireland\t'
#  '244376\t68265209\tLondon\tEnglish, Scots, Ulster, Scots, Welsh, Cornish, '
#  'Scottish, Gaelic, Irish, British Sign Language\tEurope\tGBP\tno\tno\tyes\t'
#  'yes\tyes\tmonarchy\tleft\thttps://en.wikipedia.org/wiki/United_Kingdom',
#  'overseas\toverseas\tBritish Overseas Territories\t1727415\t272256\tLondon\t'
#  'English\tWorld\tGBP\tno\tno\tyes\tyes\tyes\tmonarchy\tleft\t'
#  'https://en.wikipedia.org/wiki/British_Overseas_Territories',
#  'Antigua and Barbuda\tantigua\tAntigua and Barbuda\t440000\t100772\tSt. '
#  "John's\tEnglish, Antiguan and Barbudan Creole\tCentral America\tXCD\tno\tno\t"
#  'yes\tyes\tno\tmonarchy\tleft\t'
#  'https://en.wikipedia.org/wiki/Antigua_and_Barbuda',
#  'Australia\taustralia\tAustralia\t7688287\t27536000\tCanberra\tEnglish\t'
#  'Australia\tAUD\tno\tno\tyes\tyes\tno\tmonarchy\tleft\t'
#  'https://en.wikipedia.org/wiki/Australia',
#  'Bahamas\tbahamas\tCommonwealth of The Bahamas\t13943\t412628\tNassau\t'
#  'English, Bahamian Creole\tCentral America\tBSD, USD\tno\tno\tyes\tyes\tno\t'
#  'monarchy\tleft\thttps://en.wikipedia.org/wiki/The_Bahamas',
#  'Belize\tbelize\tBelize\t22966\t397483\tBelize City\tEnglish, Belizean '
#  'Creole\tCentral America\tBZD\tno\tno\tyes\tyes\tno\tmonarchy\tleft\t'
#  'https://en.wikipedia.org/wiki/Belize',
#  'Canada\tcanada\tCanada\t9984670\t41288599\tOttawa\tEnglish, French\tNorth '
#  'America\tCAD\tno\tno\tyes\tyes\tyes\tmonarchy\tleft\t'
#  'https://en.wikipedia.org/wiki/Canada',
#  "Grenada\tgrenada\tGrenada\t349\t124610\tSt. George's\tEnglish, Grenadian "
#  'Creole English, Grenadian Creole French\tCentral America\tXCD\tno\tno\tyes\t'
#  'yes\tno\tmonarchy\tleft\thttps://en.wikipedia.org/wiki/Grenada',
#  'Jamaica\tjamaica\tJamaica\t10991\t2734092\tKingston\tEnglish, Jamaican '
#  'Patois\tCentral America\tJMD\tno\tno\tyes\tyes\tno\tmonarchy\tleft\t'
#  'https://en.wikipedia.org/wiki/Jamaica',
#  'New Zealand\tnzeland\tNew Zealand\t268021\t5432170\tWellington\tEnglish, '
#  'Māori, NZ Sign Language\tAustralia\tNZD\tno\tno\tyes\tyes\tyes\tmonarchy\t'
#  'left\thttps://en.wikipedia.org/wiki/New_Zealand',
#  'Papua New Guinea\tpapua\tPapua New Guinea\t462840\t11781559\tPort Moresby\t'
#  'English, Hiri Motu, PNG Sign Language, Tok Pisin\tOceania\tPGK\tno\tno\tyes\t'
#  'yes\tyes\tmonarchy\tleft\thttps://en.wikipedia.org/wiki/Papua_New_Guinea',
#  'Saint Kitts and Nevis\tskn\tFederation of Saint Christopher and Nevis\t261\t'
#  '47606\tBasseterre\tEnglish, Saint Kitts Creole\tCentral America\tXCD\tno\t'
#  'no\tyes\tyes\tno\tmonarchy\tleft\t'
#  'https://en.wikipedia.org/wiki/Saint_Kitts_and_Nevis',
#  'Saint Lucia\tstlucia\tSaint Lucia\t617\t178696\tCastries\tEnglish, Saint '
#  'Lucian Creole, French\tCentral America\tXCD\tno\tno\tyes\tyes\tno\tmonarchy\t'
#  'left\thttps://en.wikipedia.org/wiki/Saint_Lucia',
#  'Saint Vincent and the Grenadines\tvincent\tSaint Vincent and the Grenadines\t'
#  '389\t110872\tKingstown\tEnglish, Vincentian Creole\tCentral America\tXCD\t'
#  'no\tno\tyes\tyes\tno\tmonarchy\tleft\t'
#  'https://en.wikipedia.org/wiki/Saint_Vincent_and_the_Grenadines',
#  'Solomon Islands \tsolomons\tSolomon Islands \t28896\t734887\tHoniara\t'
#  'English, Pijin\tOceania\tXCD\tno\tno\tyes\tyes\tno\tmonarchy\tleft\t'
#  'https://en.wikipedia.org/wiki/Solomon_Islands',
#  'Tuvalu\ttuvalu\tTuvalu\t26\t11900\tFunafuti\tTuvaluan, English\tOceania\t'
#  'AUD, TD\tno\tno\tyes\tyes\tno\tmonarchy\tleft\t'
#  'https://en.wikipedia.org/wiki/Tuvalu']

# %% [markdown]
# **Шаг 2. Преобразовать к структурам и почистить**

# %%
alist = []
for line in states[1:]:
    place = line.split("\t")
    alist.append(place)
    
pp(alist)
# Out:
# [['England',
#   'england',
#   'England',
#   '132932',
#   '57106398',
#   'London',
#   'English',
#   'Europe',
#   'GBP',
#   'no',
#   'no',
#   'yes',
#   'yes',
#   'yes',
#   'monarchy',
#   'left',
#   'https://en.wikipedia.org/wiki/England '],
#  ['Wales',
#   'wales',
#   'Wales',
#   '21218',
#   '3131640',
#   'Cardiff',
#   'English, Welsh',
#   'Europe',
#   'GBP',
#   'no',
#   'no',
#   'yes',
#   'yes',
#   'yes',
#   'monarchy',
#   'left',
#   'https://en.wikipedia.org/wiki/Wales'],
#  ['Scotland',
#   'scotland',
#   'Scotland',
#   '80231',
#   '5439842',
#   'Edinburgh',
#   'English, Scots, Scortish Gaelic, British Sign',
#   'Europe',
#   'GBP',
#   'no',
#   'no',
#   'yes',
#   'yes',
#   'yes',
#   'monarchy',
#   'left',
#   'https://en.wikipedia.org/wiki/Scotland'],
#  ['Nothern Ireland',
#   'n_ireland',
#   'Nothern Ireland',
#   '14330',
#   '1910543',
#   'Belfast',
#   'English, Irish',
#   'Europe',
#   'GBP',
#   'no',
#   'no',
#   'yes',
#   'yes',
#   'yes',
#   'monarchy',
#   'left',
#   'https://en.wikipedia.org/wiki/Northern_Ireland'],
#  ['Isle of Man',
#   'ioman',
#   'Isle of Man',
#   '574',
#   '84069',
#   'Douglas',
#   'English, Manx',
#   'Europe',
#   'GBP, IMP',
#   'no',
#   'no',
#   'yes',
#   'yes',
#   'no',
#   'monarchy',
#   'left',
#   'https://en.wikipedia.org/wiki/Isle_of_Man'],
#  ['Jersey',
#   'bei_jersey',
#   'Bailiwick of Jersey',
#   '120',
#   '103267',
#   'St.Helier',
#   'English, French, Jerriais',
#   'Europe',
#   'GBP, JEP',
#   'no',
#   'no',
#   'yes',
#   'yes',
#   'no',
#   'monarchy',
#   'left',
#   'https://en.wikipedia.org/wiki/Jersey'],
#  ['Guernsey',
#   'bei_guernsey',
#   'Bailiwick of Guernsey',
#   '78',
#   '67334',
#   'St.Peter Port',
#   'English, French, Sercquiais, Auregnais',
#   'Europe',
#   'GBP, GGP',
#   'no',
#   'no',
#   'yes',
#   'yes',
#   'no',
#   'monarchy',
#   'left',
#   'https://en.wikipedia.org/wiki/Bailiwick_of_Guernsey'],
#  ['Ireland',
#   'rep_ireland',
#   'Ireland',
#   '244376',
#   '68265209',
#   'Dublin',
#   'English, Irish',
#   'Europe',
#   'EUR',
#   'yes',
#   'yes',
#   'no',
#   'no',
#   'yes',
#   'republic',
#   'left',
#   'https://en.wikipedia.org/wiki/Ireland'],
#  ['Great Britain',
#   'britain',
#   'Great Britain',
#   '209331',
#   '65685738',
#   'London',
#   'English',
#   'Europe',
#   'GBP',
#   'no',
#   'no',
#   'yes',
#   'yes',
#   'yes',
#   'monarchy',
#   'left',
#   'https://en.wikipedia.org/wiki/Great_Britain'],
#  ['United Kingdom',
#   'uk',
#   'United Kingdom of Great Britain and Northern Ireland',
#   '244376',
#   '68265209',
#   'London',
#   'English, Scots, Ulster, Scots, Welsh, Cornish, Scottish, Gaelic, Irish, '
#   'British Sign Language',
#   'Europe',
#   'GBP',
#   'no',
#   'no',
#   'yes',
#   'yes',
#   'yes',
#   'monarchy',
#   'left',
#   'https://en.wikipedia.org/wiki/United_Kingdom'],
#  ['overseas',
#   'overseas',
#   'British Overseas Territories',
#   '1727415',
#   '272256',
#   'London',
#   'English',
#   'World',
#   'GBP',
#   'no',
#   'no',
#   'yes',
#   'yes',
#   'yes',
#   'monarchy',
#   'left',
#   'https://en.wikipedia.org/wiki/British_Overseas_Territories'],
#  ['Antigua and Barbuda',
#   'antigua',
#   'Antigua and Barbuda',
#   '440000',
#   '100772',
#   "St. John's",
#   'English, Antiguan and Barbudan Creole',
#   'Central America',
#   'XCD',
#   'no',
#   'no',
#   'yes',
#   'yes',
#   'no',
#   'monarchy',
#   'left',
#   'https://en.wikipedia.org/wiki/Antigua_and_Barbuda'],
#  ['Australia',
#   'australia',
#   'Australia',
#   '7688287',
#   '27536000',
#   'Canberra',
#   'English',
#   'Australia',
#   'AUD',
#   'no',
#   'no',
#   'yes',
#   'yes',
#   'no',
#   'monarchy',
#   'left',
#   'https://en.wikipedia.org/wiki/Australia'],
#  ['Bahamas',
#   'bahamas',
#   'Commonwealth of The Bahamas',
#   '13943',
#   '412628',
#   'Nassau',
#   'English, Bahamian Creole',
#   'Central America',
#   'BSD, USD',
#   'no',
#   'no',
#   'yes',
#   'yes',
#   'no',
#   'monarchy',
#   'left',
#   'https://en.wikipedia.org/wiki/The_Bahamas'],
#  ['Belize',
#   'belize',
#   'Belize',
#   '22966',
#   '397483',
#   'Belize City',
#   'English, Belizean Creole',
#   'Central America',
#   'BZD',
#   'no',
#   'no',
#   'yes',
#   'yes',
#   'no',
#   'monarchy',
#   'left',
#   'https://en.wikipedia.org/wiki/Belize'],
#  ['Canada',
#   'canada',
#   'Canada',
#   '9984670',
#   '41288599',
#   'Ottawa',
#   'English, French',
#   'North America',
#   'CAD',
#   'no',
#   'no',
#   'yes',
#   'yes',
#   'yes',
#   'monarchy',
#   'left',
#   'https://en.wikipedia.org/wiki/Canada'],
#  ['Grenada',
#   'grenada',
#   'Grenada',
#   '349',
#   '124610',
#   "St. George's",
#   'English, Grenadian Creole English, Grenadian Creole French',
#   'Central America',
#   'XCD',
#   'no',
#   'no',
#   'yes',
#   'yes',
#   'no',
#   'monarchy',
#   'left',
#   'https://en.wikipedia.org/wiki/Grenada'],
#  ['Jamaica',
#   'jamaica',
#   'Jamaica',
#   '10991',
#   '2734092',
#   'Kingston',
#   'English, Jamaican Patois',
#   'Central America',
#   'JMD',
#   'no',
#   'no',
#   'yes',
#   'yes',
#   'no',
#   'monarchy',
#   'left',
#   'https://en.wikipedia.org/wiki/Jamaica'],
#  ['New Zealand',
#   'nzeland',
#   'New Zealand',
#   '268021',
#   '5432170',
#   'Wellington',
#   'English, Māori, NZ Sign Language',
#   'Australia',
#   'NZD',
#   'no',
#   'no',
#   'yes',
#   'yes',
#   'yes',
#   'monarchy',
#   'left',
#   'https://en.wikipedia.org/wiki/New_Zealand'],
#  ['Papua New Guinea',
#   'papua',
#   'Papua New Guinea',
#   '462840',
#   '11781559',
#   'Port Moresby',
#   'English, Hiri Motu, PNG Sign Language, Tok Pisin',
#   'Oceania',
#   'PGK',
#   'no',
#   'no',
#   'yes',
#   'yes',
#   'yes',
#   'monarchy',
#   'left',
#   'https://en.wikipedia.org/wiki/Papua_New_Guinea'],
#  ['Saint Kitts and Nevis',
#   'skn',
#   'Federation of Saint Christopher and Nevis',
#   '261',
#   '47606',
#   'Basseterre',
#   'English, Saint Kitts Creole',
#   'Central America',
#   'XCD',
#   'no',
#   'no',
#   'yes',
#   'yes',
#   'no',
#   'monarchy',
#   'left',
#   'https://en.wikipedia.org/wiki/Saint_Kitts_and_Nevis'],
#  ['Saint Lucia',
#   'stlucia',
#   'Saint Lucia',
#   '617',
#   '178696',
#   'Castries',
#   'English, Saint Lucian Creole, French',
#   'Central America',
#   'XCD',
#   'no',
#   'no',
#   'yes',
#   'yes',
#   'no',
#   'monarchy',
#   'left',
#   'https://en.wikipedia.org/wiki/Saint_Lucia'],
#  ['Saint Vincent and the Grenadines',
#   'vincent',
#   'Saint Vincent and the Grenadines',
#   '389',
#   '110872',
#   'Kingstown',
#   'English, Vincentian Creole',
#   'Central America',
#   'XCD',
#   'no',
#   'no',
#   'yes',
#   'yes',
#   'no',
#   'monarchy',
#   'left',
#   'https://en.wikipedia.org/wiki/Saint_Vincent_and_the_Grenadines'],
#  ['Solomon Islands ',
#   'solomons',
#   'Solomon Islands ',
#   '28896',
#   '734887',
#   'Honiara',
#   'English, Pijin',
#   'Oceania',
#   'XCD',
#   'no',
#   'no',
#   'yes',
#   'yes',
#   'no',
#   'monarchy',
#   'left',
#   'https://en.wikipedia.org/wiki/Solomon_Islands'],
#  ['Tuvalu',
#   'tuvalu',
#   'Tuvalu',
#   '26',
#   '11900',
#   'Funafuti',
#   'Tuvaluan, English',
#   'Oceania',
#   'AUD, TD',
#   'no',
#   'no',
#   'yes',
#   'yes',
#   'no',
#   'monarchy',
#   'left',
#   'https://en.wikipedia.org/wiki/Tuvalu']]

# %%
names = states[0].strip().split("\t")

adict = {}
for line in states[1:]:
    item = {}
    for pos, place in enumerate(line.strip().split("\t")):
        item[ names[pos] ] = place
    adict[ item[ "code" ] ] = item
        
pp(adict)
# Out:
# {'england': {'name': 'England',
#              'code': 'england',
#              'official': 'England',
#              'territory': '132932',
#              'population': '57106398',
#              'capital': 'London',
#              'languages': 'English',
#              'world': 'Europe',
#              'currency': 'GBP',
#              'EU': 'no',
#              'Shengen': 'no',
#              'Commonwealth': 'yes',
#              'Realm': 'yes',
#              'NATO': 'yes',
#              'power': 'monarchy',
#              'driveson': 'left',
#              'wiki': 'https://en.wikipedia.org/wiki/England'},
#  'wales': {'name': 'Wales',
#            'code': 'wales',
#            'official': 'Wales',
#            'territory': '21218',
#            'population': '3131640',
#            'capital': 'Cardiff',
#            'languages': 'English, Welsh',
#            'world': 'Europe',
#            'currency': 'GBP',
#            'EU': 'no',
#            'Shengen': 'no',
#            'Commonwealth': 'yes',
#            'Realm': 'yes',
#            'NATO': 'yes',
#            'power': 'monarchy',
#            'driveson': 'left',
#            'wiki': 'https://en.wikipedia.org/wiki/Wales'},
#  'scotland': {'name': 'Scotland',
#               'code': 'scotland',
#               'official': 'Scotland',
#               'territory': '80231',
#               'population': '5439842',
#               'capital': 'Edinburgh',
#               'languages': 'English, Scots, Scortish Gaelic, British Sign',
#               'world': 'Europe',
#               'currency': 'GBP',
#               'EU': 'no',
#               'Shengen': 'no',
#               'Commonwealth': 'yes',
#               'Realm': 'yes',
#               'NATO': 'yes',
#               'power': 'monarchy',
#               'driveson': 'left',
#               'wiki': 'https://en.wikipedia.org/wiki/Scotland'},
#  'n_ireland': {'name': 'Nothern Ireland',
#                'code': 'n_ireland',
#                'official': 'Nothern Ireland',
#                'territory': '14330',
#                'population': '1910543',
#                'capital': 'Belfast',
#                'languages': 'English, Irish',
#                'world': 'Europe',
#                'currency': 'GBP',
#                'EU': 'no',
#                'Shengen': 'no',
#                'Commonwealth': 'yes',
#                'Realm': 'yes',
#                'NATO': 'yes',
#                'power': 'monarchy',
#                'driveson': 'left',
#                'wiki': 'https://en.wikipedia.org/wiki/Northern_Ireland'},
#  'ioman': {'name': 'Isle of Man',
#            'code': 'ioman',
#            'official': 'Isle of Man',
#            'territory': '574',
#            'population': '84069',
#            'capital': 'Douglas',
#            'languages': 'English, Manx',
#            'world': 'Europe',
#            'currency': 'GBP, IMP',
#            'EU': 'no',
#            'Shengen': 'no',
#            'Commonwealth': 'yes',
#            'Realm': 'yes',
#            'NATO': 'no',
#            'power': 'monarchy',
#            'driveson': 'left',
#            'wiki': 'https://en.wikipedia.org/wiki/Isle_of_Man'},
#  'bei_jersey': {'name': 'Jersey',
#                 'code': 'bei_jersey',
#                 'official': 'Bailiwick of Jersey',
#                 'territory': '120',
#                 'population': '103267',
#                 'capital': 'St.Helier',
#                 'languages': 'English, French, Jerriais',
#                 'world': 'Europe',
#                 'currency': 'GBP, JEP',
#                 'EU': 'no',
#                 'Shengen': 'no',
#                 'Commonwealth': 'yes',
#                 'Realm': 'yes',
#                 'NATO': 'no',
#                 'power': 'monarchy',
#                 'driveson': 'left',
#                 'wiki': 'https://en.wikipedia.org/wiki/Jersey'},
#  'bei_guernsey': {'name': 'Guernsey',
#                   'code': 'bei_guernsey',
#                   'official': 'Bailiwick of Guernsey',
#                   'territory': '78',
#                   'population': '67334',
#                   'capital': 'St.Peter Port',
#                   'languages': 'English, French, Sercquiais, Auregnais',
#                   'world': 'Europe',
#                   'currency': 'GBP, GGP',
#                   'EU': 'no',
#                   'Shengen': 'no',
#                   'Commonwealth': 'yes',
#                   'Realm': 'yes',
#                   'NATO': 'no',
#                   'power': 'monarchy',
#                   'driveson': 'left',
#                   'wiki': 'https://en.wikipedia.org/wiki/Bailiwick_of_Guernsey'},
#  'rep_ireland': {'name': 'Ireland',
#                  'code': 'rep_ireland',
#                  'official': 'Ireland',
#                  'territory': '244376',
#                  'population': '68265209',
#                  'capital': 'Dublin',
#                  'languages': 'English, Irish',
#                  'world': 'Europe',
#                  'currency': 'EUR',
#                  'EU': 'yes',
#                  'Shengen': 'yes',
#                  'Commonwealth': 'no',
#                  'Realm': 'no',
#                  'NATO': 'yes',
#                  'power': 'republic',
#                  'driveson': 'left',
#                  'wiki': 'https://en.wikipedia.org/wiki/Ireland'},
#  'britain': {'name': 'Great Britain',
#              'code': 'britain',
#              'official': 'Great Britain',
#              'territory': '209331',
#              'population': '65685738',
#              'capital': 'London',
#              'languages': 'English',
#              'world': 'Europe',
#              'currency': 'GBP',
#              'EU': 'no',
#              'Shengen': 'no',
#              'Commonwealth': 'yes',
#              'Realm': 'yes',
#              'NATO': 'yes',
#              'power': 'monarchy',
#              'driveson': 'left',
#              'wiki': 'https://en.wikipedia.org/wiki/Great_Britain'},
#  'uk': {'name': 'United Kingdom',
#         'code': 'uk',
#         'official': 'United Kingdom of Great Britain and Northern Ireland',
#         'territory': '244376',
#         'population': '68265209',
#         'capital': 'London',
#         'languages': 'English, Scots, Ulster, Scots, Welsh, Cornish, Scottish, '
#                      'Gaelic, Irish, British Sign Language',
#         'world': 'Europe',
#         'currency': 'GBP',
#         'EU': 'no',
#         'Shengen': 'no',
#         'Commonwealth': 'yes',
#         'Realm': 'yes',
#         'NATO': 'yes',
#         'power': 'monarchy',
#         'driveson': 'left',
#         'wiki': 'https://en.wikipedia.org/wiki/United_Kingdom'},
#  'overseas': {'name': 'overseas',
#               'code': 'overseas',
#               'official': 'British Overseas Territories',
#               'territory': '1727415',
#               'population': '272256',
#               'capital': 'London',
#               'languages': 'English',
#               'world': 'World',
#               'currency': 'GBP',
#               'EU': 'no',
#               'Shengen': 'no',
#               'Commonwealth': 'yes',
#               'Realm': 'yes',
#               'NATO': 'yes',
#               'power': 'monarchy',
#               'driveson': 'left',
#               'wiki': 'https://en.wikipedia.org/wiki/British_Overseas_Territories'},
#  'antigua': {'name': 'Antigua and Barbuda',
#              'code': 'antigua',
#              'official': 'Antigua and Barbuda',
#              'territory': '440000',
#              'population': '100772',
#              'capital': "St. John's",
#              'languages': 'English, Antiguan and Barbudan Creole',
#              'world': 'Central America',
#              'currency': 'XCD',
#              'EU': 'no',
#              'Shengen': 'no',
#              'Commonwealth': 'yes',
#              'Realm': 'yes',
#              'NATO': 'no',
#              'power': 'monarchy',
#              'driveson': 'left',
#              'wiki': 'https://en.wikipedia.org/wiki/Antigua_and_Barbuda'},
#  'australia': {'name': 'Australia',
#                'code': 'australia',
#                'official': 'Australia',
#                'territory': '7688287',
#                'population': '27536000',
#                'capital': 'Canberra',
#                'languages': 'English',
#                'world': 'Australia',
#                'currency': 'AUD',
#                'EU': 'no',
#                'Shengen': 'no',
#                'Commonwealth': 'yes',
#                'Realm': 'yes',
#                'NATO': 'no',
#                'power': 'monarchy',
#                'driveson': 'left',
#                'wiki': 'https://en.wikipedia.org/wiki/Australia'},
#  'bahamas': {'name': 'Bahamas',
#              'code': 'bahamas',
#              'official': 'Commonwealth of The Bahamas',
#              'territory': '13943',
#              'population': '412628',
#              'capital': 'Nassau',
#              'languages': 'English, Bahamian Creole',
#              'world': 'Central America',
#              'currency': 'BSD, USD',
#              'EU': 'no',
#              'Shengen': 'no',
#              'Commonwealth': 'yes',
#              'Realm': 'yes',
#              'NATO': 'no',
#              'power': 'monarchy',
#              'driveson': 'left',
#              'wiki': 'https://en.wikipedia.org/wiki/The_Bahamas'},
#  'belize': {'name': 'Belize',
#             'code': 'belize',
#             'official': 'Belize',
#             'territory': '22966',
#             'population': '397483',
#             'capital': 'Belize City',
#             'languages': 'English, Belizean Creole',
#             'world': 'Central America',
#             'currency': 'BZD',
#             'EU': 'no',
#             'Shengen': 'no',
#             'Commonwealth': 'yes',
#             'Realm': 'yes',
#             'NATO': 'no',
#             'power': 'monarchy',
#             'driveson': 'left',
#             'wiki': 'https://en.wikipedia.org/wiki/Belize'},
#  'canada': {'name': 'Canada',
#             'code': 'canada',
#             'official': 'Canada',
#             'territory': '9984670',
#             'population': '41288599',
#             'capital': 'Ottawa',
#             'languages': 'English, French',
#             'world': 'North America',
#             'currency': 'CAD',
#             'EU': 'no',
#             'Shengen': 'no',
#             'Commonwealth': 'yes',
#             'Realm': 'yes',
#             'NATO': 'yes',
#             'power': 'monarchy',
#             'driveson': 'left',
#             'wiki': 'https://en.wikipedia.org/wiki/Canada'},
#  'grenada': {'name': 'Grenada',
#              'code': 'grenada',
#              'official': 'Grenada',
#              'territory': '349',
#              'population': '124610',
#              'capital': "St. George's",
#              'languages': 'English, Grenadian Creole English, Grenadian Creole '
#                           'French',
#              'world': 'Central America',
#              'currency': 'XCD',
#              'EU': 'no',
#              'Shengen': 'no',
#              'Commonwealth': 'yes',
#              'Realm': 'yes',
#              'NATO': 'no',
#              'power': 'monarchy',
#              'driveson': 'left',
#              'wiki': 'https://en.wikipedia.org/wiki/Grenada'},
#  'jamaica': {'name': 'Jamaica',
#              'code': 'jamaica',
#              'official': 'Jamaica',
#              'territory': '10991',
#              'population': '2734092',
#              'capital': 'Kingston',
#              'languages': 'English, Jamaican Patois',
#              'world': 'Central America',
#              'currency': 'JMD',
#              'EU': 'no',
#              'Shengen': 'no',
#              'Commonwealth': 'yes',
#              'Realm': 'yes',
#              'NATO': 'no',
#              'power': 'monarchy',
#              'driveson': 'left',
#              'wiki': 'https://en.wikipedia.org/wiki/Jamaica'},
#  'nzeland': {'name': 'New Zealand',
#              'code': 'nzeland',
#              'official': 'New Zealand',
#              'territory': '268021',
#              'population': '5432170',
#              'capital': 'Wellington',
#              'languages': 'English, Māori, NZ Sign Language',
#              'world': 'Australia',
#              'currency': 'NZD',
#              'EU': 'no',
#              'Shengen': 'no',
#              'Commonwealth': 'yes',
#              'Realm': 'yes',
#              'NATO': 'yes',
#              'power': 'monarchy',
#              'driveson': 'left',
#              'wiki': 'https://en.wikipedia.org/wiki/New_Zealand'},
#  'papua': {'name': 'Papua New Guinea',
#            'code': 'papua',
#            'official': 'Papua New Guinea',
#            'territory': '462840',
#            'population': '11781559',
#            'capital': 'Port Moresby',
#            'languages': 'English, Hiri Motu, PNG Sign Language, Tok Pisin',
#            'world': 'Oceania',
#            'currency': 'PGK',
#            'EU': 'no',
#            'Shengen': 'no',
#            'Commonwealth': 'yes',
#            'Realm': 'yes',
#            'NATO': 'yes',
#            'power': 'monarchy',
#            'driveson': 'left',
#            'wiki': 'https://en.wikipedia.org/wiki/Papua_New_Guinea'},
#  'skn': {'name': 'Saint Kitts and Nevis',
#          'code': 'skn',
#          'official': 'Federation of Saint Christopher and Nevis',
#          'territory': '261',
#          'population': '47606',
#          'capital': 'Basseterre',
#          'languages': 'English, Saint Kitts Creole',
#          'world': 'Central America',
#          'currency': 'XCD',
#          'EU': 'no',
#          'Shengen': 'no',
#          'Commonwealth': 'yes',
#          'Realm': 'yes',
#          'NATO': 'no',
#          'power': 'monarchy',
#          'driveson': 'left',
#          'wiki': 'https://en.wikipedia.org/wiki/Saint_Kitts_and_Nevis'},
#  'stlucia': {'name': 'Saint Lucia',
#              'code': 'stlucia',
#              'official': 'Saint Lucia',
#              'territory': '617',
#              'population': '178696',
#              'capital': 'Castries',
#              'languages': 'English, Saint Lucian Creole, French',
#              'world': 'Central America',
#              'currency': 'XCD',
#              'EU': 'no',
#              'Shengen': 'no',
#              'Commonwealth': 'yes',
#              'Realm': 'yes',
#              'NATO': 'no',
#              'power': 'monarchy',
#              'driveson': 'left',
#              'wiki': 'https://en.wikipedia.org/wiki/Saint_Lucia'},
#  'vincent': {'name': 'Saint Vincent and the Grenadines',
#              'code': 'vincent',
#              'official': 'Saint Vincent and the Grenadines',
#              'territory': '389',
#              'population': '110872',
#              'capital': 'Kingstown',
#              'languages': 'English, Vincentian Creole',
#              'world': 'Central America',
#              'currency': 'XCD',
#              'EU': 'no',
#              'Shengen': 'no',
#              'Commonwealth': 'yes',
#              'Realm': 'yes',
#              'NATO': 'no',
#              'power': 'monarchy',
#              'driveson': 'left',
#              'wiki': 'https://en.wikipedia.org/wiki/Saint_Vincent_and_the_Grenadines'},
#  'solomons': {'name': 'Solomon Islands ',
#               'code': 'solomons',
#               'official': 'Solomon Islands ',
#               'territory': '28896',
#               'population': '734887',
#               'capital': 'Honiara',
#               'languages': 'English, Pijin',
#               'world': 'Oceania',
#               'currency': 'XCD',
#               'EU': 'no',
#               'Shengen': 'no',
#               'Commonwealth': 'yes',
#               'Realm': 'yes',
#               'NATO': 'no',
#               'power': 'monarchy',
#               'driveson': 'left',
#               'wiki': 'https://en.wikipedia.org/wiki/Solomon_Islands'},
#  'tuvalu': {'name': 'Tuvalu',
#             'code': 'tuvalu',
#             'official': 'Tuvalu',
#             'territory': '26',
#             'population': '11900',
#             'capital': 'Funafuti',
#             'languages': 'Tuvaluan, English',
#             'world': 'Oceania',
#             'currency': 'AUD, TD',
#             'EU': 'no',
#             'Shengen': 'no',
#             'Commonwealth': 'yes',
#             'Realm': 'yes',
#             'NATO': 'no',
#             'power': 'monarchy',
#             'driveson': 'left',
#             'wiki': 'https://en.wikipedia.org/wiki/Tuvalu'}}

# %% [markdown]
# **Шаг 3. Преобразовать типы к удобным для обработки:**
# 1. приведём к  целым числам данные о площади и населении,
# 2. сделаем доп список языков из соотв. строки, убрав пробелы и запятые

# %%
for place, desc in adict.items():
    desc["territory"] = int(desc["territory"])
    desc["population"] = int(desc["population"])
    desc["langlist"] = list( map( str.strip, desc["languages"] .split(",") ) ) 
    desc["curlist"] = list( map( str.strip, desc["currency"] .split(",") ) ) 

pp(adict)
# Out:
# {'england': {'name': 'England',
#              'code': 'england',
#              'official': 'England',
#              'territory': 132932,
#              'population': 57106398,
#              'capital': 'London',
#              'languages': 'English',
#              'world': 'Europe',
#              'currency': 'GBP',
#              'EU': 'no',
#              'Shengen': 'no',
#              'Commonwealth': 'yes',
#              'Realm': 'yes',
#              'NATO': 'yes',
#              'power': 'monarchy',
#              'driveson': 'left',
#              'wiki': 'https://en.wikipedia.org/wiki/England',
#              'langlist': ['English'],
#              'curlist': ['GBP']},
#  'wales': {'name': 'Wales',
#            'code': 'wales',
#            'official': 'Wales',
#            'territory': 21218,
#            'population': 3131640,
#            'capital': 'Cardiff',
#            'languages': 'English, Welsh',
#            'world': 'Europe',
#            'currency': 'GBP',
#            'EU': 'no',
#            'Shengen': 'no',
#            'Commonwealth': 'yes',
#            'Realm': 'yes',
#            'NATO': 'yes',
#            'power': 'monarchy',
#            'driveson': 'left',
#            'wiki': 'https://en.wikipedia.org/wiki/Wales',
#            'langlist': ['English', 'Welsh'],
#            'curlist': ['GBP']},
#  'scotland': {'name': 'Scotland',
#               'code': 'scotland',
#               'official': 'Scotland',
#               'territory': 80231,
#               'population': 5439842,
#               'capital': 'Edinburgh',
#               'languages': 'English, Scots, Scortish Gaelic, British Sign',
#               'world': 'Europe',
#               'currency': 'GBP',
#               'EU': 'no',
#               'Shengen': 'no',
#               'Commonwealth': 'yes',
#               'Realm': 'yes',
#               'NATO': 'yes',
#               'power': 'monarchy',
#               'driveson': 'left',
#               'wiki': 'https://en.wikipedia.org/wiki/Scotland',
#               'langlist': ['English',
#                            'Scots',
#                            'Scortish Gaelic',
#                            'British Sign'],
#               'curlist': ['GBP']},
#  'n_ireland': {'name': 'Nothern Ireland',
#                'code': 'n_ireland',
#                'official': 'Nothern Ireland',
#                'territory': 14330,
#                'population': 1910543,
#                'capital': 'Belfast',
#                'languages': 'English, Irish',
#                'world': 'Europe',
#                'currency': 'GBP',
#                'EU': 'no',
#                'Shengen': 'no',
#                'Commonwealth': 'yes',
#                'Realm': 'yes',
#                'NATO': 'yes',
#                'power': 'monarchy',
#                'driveson': 'left',
#                'wiki': 'https://en.wikipedia.org/wiki/Northern_Ireland',
#                'langlist': ['English', 'Irish'],
#                'curlist': ['GBP']},
#  'ioman': {'name': 'Isle of Man',
#            'code': 'ioman',
#            'official': 'Isle of Man',
#            'territory': 574,
#            'population': 84069,
#            'capital': 'Douglas',
#            'languages': 'English, Manx',
#            'world': 'Europe',
#            'currency': 'GBP, IMP',
#            'EU': 'no',
#            'Shengen': 'no',
#            'Commonwealth': 'yes',
#            'Realm': 'yes',
#            'NATO': 'no',
#            'power': 'monarchy',
#            'driveson': 'left',
#            'wiki': 'https://en.wikipedia.org/wiki/Isle_of_Man',
#            'langlist': ['English', 'Manx'],
#            'curlist': ['GBP', 'IMP']},
#  'bei_jersey': {'name': 'Jersey',
#                 'code': 'bei_jersey',
#                 'official': 'Bailiwick of Jersey',
#                 'territory': 120,
#                 'population': 103267,
#                 'capital': 'St.Helier',
#                 'languages': 'English, French, Jerriais',
#                 'world': 'Europe',
#                 'currency': 'GBP, JEP',
#                 'EU': 'no',
#                 'Shengen': 'no',
#                 'Commonwealth': 'yes',
#                 'Realm': 'yes',
#                 'NATO': 'no',
#                 'power': 'monarchy',
#                 'driveson': 'left',
#                 'wiki': 'https://en.wikipedia.org/wiki/Jersey',
#                 'langlist': ['English', 'French', 'Jerriais'],
#                 'curlist': ['GBP', 'JEP']},
#  'bei_guernsey': {'name': 'Guernsey',
#                   'code': 'bei_guernsey',
#                   'official': 'Bailiwick of Guernsey',
#                   'territory': 78,
#                   'population': 67334,
#                   'capital': 'St.Peter Port',
#                   'languages': 'English, French, Sercquiais, Auregnais',
#                   'world': 'Europe',
#                   'currency': 'GBP, GGP',
#                   'EU': 'no',
#                   'Shengen': 'no',
#                   'Commonwealth': 'yes',
#                   'Realm': 'yes',
#                   'NATO': 'no',
#                   'power': 'monarchy',
#                   'driveson': 'left',
#                   'wiki': 'https://en.wikipedia.org/wiki/Bailiwick_of_Guernsey',
#                   'langlist': ['English', 'French', 'Sercquiais', 'Auregnais'],
#                   'curlist': ['GBP', 'GGP']},
#  'rep_ireland': {'name': 'Ireland',
#                  'code': 'rep_ireland',
#                  'official': 'Ireland',
#                  'territory': 244376,
#                  'population': 68265209,
#                  'capital': 'Dublin',
#                  'languages': 'English, Irish',
#                  'world': 'Europe',
#                  'currency': 'EUR',
#                  'EU': 'yes',
#                  'Shengen': 'yes',
#                  'Commonwealth': 'no',
#                  'Realm': 'no',
#                  'NATO': 'yes',
#                  'power': 'republic',
#                  'driveson': 'left',
#                  'wiki': 'https://en.wikipedia.org/wiki/Ireland',
#                  'langlist': ['English', 'Irish'],
#                  'curlist': ['EUR']},
#  'britain': {'name': 'Great Britain',
#              'code': 'britain',
#              'official': 'Great Britain',
#              'territory': 209331,
#              'population': 65685738,
#              'capital': 'London',
#              'languages': 'English',
#              'world': 'Europe',
#              'currency': 'GBP',
#              'EU': 'no',
#              'Shengen': 'no',
#              'Commonwealth': 'yes',
#              'Realm': 'yes',
#              'NATO': 'yes',
#              'power': 'monarchy',
#              'driveson': 'left',
#              'wiki': 'https://en.wikipedia.org/wiki/Great_Britain',
#              'langlist': ['English'],
#              'curlist': ['GBP']},
#  'uk': {'name': 'United Kingdom',
#         'code': 'uk',
#         'official': 'United Kingdom of Great Britain and Northern Ireland',
#         'territory': 244376,
#         'population': 68265209,
#         'capital': 'London',
#         'languages': 'English, Scots, Ulster, Scots, Welsh, Cornish, Scottish, '
#                      'Gaelic, Irish, British Sign Language',
#         'world': 'Europe',
#         'currency': 'GBP',
#         'EU': 'no',
#         'Shengen': 'no',
#         'Commonwealth': 'yes',
#         'Realm': 'yes',
#         'NATO': 'yes',
#         'power': 'monarchy',
#         'driveson': 'left',
#         'wiki': 'https://en.wikipedia.org/wiki/United_Kingdom',
#         'langlist': ['English',
#                      'Scots',
#                      'Ulster',
#                      'Scots',
#                      'Welsh',
#                      'Cornish',
#                      'Scottish',
#                      'Gaelic',
#                      'Irish',
#                      'British Sign Language'],
#         'curlist': ['GBP']},
#  'overseas': {'name': 'overseas',
#               'code': 'overseas',
#               'official': 'British Overseas Territories',
#               'territory': 1727415,
#               'population': 272256,
#               'capital': 'London',
#               'languages': 'English',
#               'world': 'World',
#               'currency': 'GBP',
#               'EU': 'no',
#               'Shengen': 'no',
#               'Commonwealth': 'yes',
#               'Realm': 'yes',
#               'NATO': 'yes',
#               'power': 'monarchy',
#               'driveson': 'left',
#               'wiki': 'https://en.wikipedia.org/wiki/British_Overseas_Territories',
#               'langlist': ['English'],
#               'curlist': ['GBP']},
#  'antigua': {'name': 'Antigua and Barbuda',
#              'code': 'antigua',
#              'official': 'Antigua and Barbuda',
#              'territory': 440000,
#              'population': 100772,
#              'capital': "St. John's",
#              'languages': 'English, Antiguan and Barbudan Creole',
#              'world': 'Central America',
#              'currency': 'XCD',
#              'EU': 'no',
#              'Shengen': 'no',
#              'Commonwealth': 'yes',
#              'Realm': 'yes',
#              'NATO': 'no',
#              'power': 'monarchy',
#              'driveson': 'left',
#              'wiki': 'https://en.wikipedia.org/wiki/Antigua_and_Barbuda',
#              'langlist': ['English', 'Antiguan and Barbudan Creole'],
#              'curlist': ['XCD']},
#  'australia': {'name': 'Australia',
#                'code': 'australia',
#                'official': 'Australia',
#                'territory': 7688287,
#                'population': 27536000,
#                'capital': 'Canberra',
#                'languages': 'English',
#                'world': 'Australia',
#                'currency': 'AUD',
#                'EU': 'no',
#                'Shengen': 'no',
#                'Commonwealth': 'yes',
#                'Realm': 'yes',
#                'NATO': 'no',
#                'power': 'monarchy',
#                'driveson': 'left',
#                'wiki': 'https://en.wikipedia.org/wiki/Australia',
#                'langlist': ['English'],
#                'curlist': ['AUD']},
#  'bahamas': {'name': 'Bahamas',
#              'code': 'bahamas',
#              'official': 'Commonwealth of The Bahamas',
#              'territory': 13943,
#              'population': 412628,
#              'capital': 'Nassau',
#              'languages': 'English, Bahamian Creole',
#              'world': 'Central America',
#              'currency': 'BSD, USD',
#              'EU': 'no',
#              'Shengen': 'no',
#              'Commonwealth': 'yes',
#              'Realm': 'yes',
#              'NATO': 'no',
#              'power': 'monarchy',
#              'driveson': 'left',
#              'wiki': 'https://en.wikipedia.org/wiki/The_Bahamas',
#              'langlist': ['English', 'Bahamian Creole'],
#              'curlist': ['BSD', 'USD']},
#  'belize': {'name': 'Belize',
#             'code': 'belize',
#             'official': 'Belize',
#             'territory': 22966,
#             'population': 397483,
#             'capital': 'Belize City',
#             'languages': 'English, Belizean Creole',
#             'world': 'Central America',
#             'currency': 'BZD',
#             'EU': 'no',
#             'Shengen': 'no',
#             'Commonwealth': 'yes',
#             'Realm': 'yes',
#             'NATO': 'no',
#             'power': 'monarchy',
#             'driveson': 'left',
#             'wiki': 'https://en.wikipedia.org/wiki/Belize',
#             'langlist': ['English', 'Belizean Creole'],
#             'curlist': ['BZD']},
#  'canada': {'name': 'Canada',
#             'code': 'canada',
#             'official': 'Canada',
#             'territory': 9984670,
#             'population': 41288599,
#             'capital': 'Ottawa',
#             'languages': 'English, French',
#             'world': 'North America',
#             'currency': 'CAD',
#             'EU': 'no',
#             'Shengen': 'no',
#             'Commonwealth': 'yes',
#             'Realm': 'yes',
#             'NATO': 'yes',
#             'power': 'monarchy',
#             'driveson': 'left',
#             'wiki': 'https://en.wikipedia.org/wiki/Canada',
#             'langlist': ['English', 'French'],
#             'curlist': ['CAD']},
#  'grenada': {'name': 'Grenada',
#              'code': 'grenada',
#              'official': 'Grenada',
#              'territory': 349,
#              'population': 124610,
#              'capital': "St. George's",
#              'languages': 'English, Grenadian Creole English, Grenadian Creole '
#                           'French',
#              'world': 'Central America',
#              'currency': 'XCD',
#              'EU': 'no',
#              'Shengen': 'no',
#              'Commonwealth': 'yes',
#              'Realm': 'yes',
#              'NATO': 'no',
#              'power': 'monarchy',
#              'driveson': 'left',
#              'wiki': 'https://en.wikipedia.org/wiki/Grenada',
#              'langlist': ['English',
#                           'Grenadian Creole English',
#                           'Grenadian Creole French'],
#              'curlist': ['XCD']},
#  'jamaica': {'name': 'Jamaica',
#              'code': 'jamaica',
#              'official': 'Jamaica',
#              'territory': 10991,
#              'population': 2734092,
#              'capital': 'Kingston',
#              'languages': 'English, Jamaican Patois',
#              'world': 'Central America',
#              'currency': 'JMD',
#              'EU': 'no',
#              'Shengen': 'no',
#              'Commonwealth': 'yes',
#              'Realm': 'yes',
#              'NATO': 'no',
#              'power': 'monarchy',
#              'driveson': 'left',
#              'wiki': 'https://en.wikipedia.org/wiki/Jamaica',
#              'langlist': ['English', 'Jamaican Patois'],
#              'curlist': ['JMD']},
#  'nzeland': {'name': 'New Zealand',
#              'code': 'nzeland',
#              'official': 'New Zealand',
#              'territory': 268021,
#              'population': 5432170,
#              'capital': 'Wellington',
#              'languages': 'English, Māori, NZ Sign Language',
#              'world': 'Australia',
#              'currency': 'NZD',
#              'EU': 'no',
#              'Shengen': 'no',
#              'Commonwealth': 'yes',
#              'Realm': 'yes',
#              'NATO': 'yes',
#              'power': 'monarchy',
#              'driveson': 'left',
#              'wiki': 'https://en.wikipedia.org/wiki/New_Zealand',
#              'langlist': ['English', 'Māori', 'NZ Sign Language'],
#              'curlist': ['NZD']},
#  'papua': {'name': 'Papua New Guinea',
#            'code': 'papua',
#            'official': 'Papua New Guinea',
#            'territory': 462840,
#            'population': 11781559,
#            'capital': 'Port Moresby',
#            'languages': 'English, Hiri Motu, PNG Sign Language, Tok Pisin',
#            'world': 'Oceania',
#            'currency': 'PGK',
#            'EU': 'no',
#            'Shengen': 'no',
#            'Commonwealth': 'yes',
#            'Realm': 'yes',
#            'NATO': 'yes',
#            'power': 'monarchy',
#            'driveson': 'left',
#            'wiki': 'https://en.wikipedia.org/wiki/Papua_New_Guinea',
#            'langlist': ['English',
#                         'Hiri Motu',
#                         'PNG Sign Language',
#                         'Tok Pisin'],
#            'curlist': ['PGK']},
#  'skn': {'name': 'Saint Kitts and Nevis',
#          'code': 'skn',
#          'official': 'Federation of Saint Christopher and Nevis',
#          'territory': 261,
#          'population': 47606,
#          'capital': 'Basseterre',
#          'languages': 'English, Saint Kitts Creole',
#          'world': 'Central America',
#          'currency': 'XCD',
#          'EU': 'no',
#          'Shengen': 'no',
#          'Commonwealth': 'yes',
#          'Realm': 'yes',
#          'NATO': 'no',
#          'power': 'monarchy',
#          'driveson': 'left',
#          'wiki': 'https://en.wikipedia.org/wiki/Saint_Kitts_and_Nevis',
#          'langlist': ['English', 'Saint Kitts Creole'],
#          'curlist': ['XCD']},
#  'stlucia': {'name': 'Saint Lucia',
#              'code': 'stlucia',
#              'official': 'Saint Lucia',
#              'territory': 617,
#              'population': 178696,
#              'capital': 'Castries',
#              'languages': 'English, Saint Lucian Creole, French',
#              'world': 'Central America',
#              'currency': 'XCD',
#              'EU': 'no',
#              'Shengen': 'no',
#              'Commonwealth': 'yes',
#              'Realm': 'yes',
#              'NATO': 'no',
#              'power': 'monarchy',
#              'driveson': 'left',
#              'wiki': 'https://en.wikipedia.org/wiki/Saint_Lucia',
#              'langlist': ['English', 'Saint Lucian Creole', 'French'],
#              'curlist': ['XCD']},
#  'vincent': {'name': 'Saint Vincent and the Grenadines',
#              'code': 'vincent',
#              'official': 'Saint Vincent and the Grenadines',
#              'territory': 389,
#              'population': 110872,
#              'capital': 'Kingstown',
#              'languages': 'English, Vincentian Creole',
#              'world': 'Central America',
#              'currency': 'XCD',
#              'EU': 'no',
#              'Shengen': 'no',
#              'Commonwealth': 'yes',
#              'Realm': 'yes',
#              'NATO': 'no',
#              'power': 'monarchy',
#              'driveson': 'left',
#              'wiki': 'https://en.wikipedia.org/wiki/Saint_Vincent_and_the_Grenadines',
#              'langlist': ['English', 'Vincentian Creole'],
#              'curlist': ['XCD']},
#  'solomons': {'name': 'Solomon Islands ',
#               'code': 'solomons',
#               'official': 'Solomon Islands ',
#               'territory': 28896,
#               'population': 734887,
#               'capital': 'Honiara',
#               'languages': 'English, Pijin',
#               'world': 'Oceania',
#               'currency': 'XCD',
#               'EU': 'no',
#               'Shengen': 'no',
#               'Commonwealth': 'yes',
#               'Realm': 'yes',
#               'NATO': 'no',
#               'power': 'monarchy',
#               'driveson': 'left',
#               'wiki': 'https://en.wikipedia.org/wiki/Solomon_Islands',
#               'langlist': ['English', 'Pijin'],
#               'curlist': ['XCD']},
#  'tuvalu': {'name': 'Tuvalu',
#             'code': 'tuvalu',
#             'official': 'Tuvalu',
#             'territory': 26,
#             'population': 11900,
#             'capital': 'Funafuti',
#             'languages': 'Tuvaluan, English',
#             'world': 'Oceania',
#             'currency': 'AUD, TD',
#             'EU': 'no',
#             'Shengen': 'no',
#             'Commonwealth': 'yes',
#             'Realm': 'yes',
#             'NATO': 'no',
#             'power': 'monarchy',
#             'driveson': 'left',
#             'wiki': 'https://en.wikipedia.org/wiki/Tuvalu',
#             'langlist': ['Tuvaluan', 'English'],
#             'curlist': ['AUD', 'TD']}}

# %% [markdown]
# Теперь все данные обработаны, можно извлекать из них полезную информацию.

# %% [markdown]
# **Шаг 4. Называем и группируем страны**

# %%
england = adict['england']
pp(england)
# Out:
# {'name': 'England',
#  'code': 'england',
#  'official': 'England',
#  'territory': 132932,
#  'population': 57106398,
#  'capital': 'London',
#  'languages': 'English',
#  'world': 'Europe',
#  'currency': 'GBP',
#  'EU': 'no',
#  'Shengen': 'no',
#  'Commonwealth': 'yes',
#  'Realm': 'yes',
#  'NATO': 'yes',
#  'power': 'monarchy',
#  'driveson': 'left',
#  'wiki': 'https://en.wikipedia.org/wiki/England',
#  'langlist': ['English'],
#  'curlist': ['GBP']}

# %%
wales = adict['wales']
scotland = adict['scotland']
n_ireland = adict['n_ireland']

ioman = adict['ioman']
jersey = adict['bei_jersey']
guernsey = adict['bei_guernsey']

# %%
isle_gb = [england, wales, scotland]
pp(isle_gb)
# Out:
# [{'name': 'England',
#   'code': 'england',
#   'official': 'England',
#   'territory': 132932,
#   'population': 57106398,
#   'capital': 'London',
#   'languages': 'English',
#   'world': 'Europe',
#   'currency': 'GBP',
#   'EU': 'no',
#   'Shengen': 'no',
#   'Commonwealth': 'yes',
#   'Realm': 'yes',
#   'NATO': 'yes',
#   'power': 'monarchy',
#   'driveson': 'left',
#   'wiki': 'https://en.wikipedia.org/wiki/England',
#   'langlist': ['English'],
#   'curlist': ['GBP']},
#  {'name': 'Wales',
#   'code': 'wales',
#   'official': 'Wales',
#   'territory': 21218,
#   'population': 3131640,
#   'capital': 'Cardiff',
#   'languages': 'English, Welsh',
#   'world': 'Europe',
#   'currency': 'GBP',
#   'EU': 'no',
#   'Shengen': 'no',
#   'Commonwealth': 'yes',
#   'Realm': 'yes',
#   'NATO': 'yes',
#   'power': 'monarchy',
#   'driveson': 'left',
#   'wiki': 'https://en.wikipedia.org/wiki/Wales',
#   'langlist': ['English', 'Welsh'],
#   'curlist': ['GBP']},
#  {'name': 'Scotland',
#   'code': 'scotland',
#   'official': 'Scotland',
#   'territory': 80231,
#   'population': 5439842,
#   'capital': 'Edinburgh',
#   'languages': 'English, Scots, Scortish Gaelic, British Sign',
#   'world': 'Europe',
#   'currency': 'GBP',
#   'EU': 'no',
#   'Shengen': 'no',
#   'Commonwealth': 'yes',
#   'Realm': 'yes',
#   'NATO': 'yes',
#   'power': 'monarchy',
#   'driveson': 'left',
#   'wiki': 'https://en.wikipedia.org/wiki/Scotland',
#   'langlist': ['English', 'Scots', 'Scortish Gaelic', 'British Sign'],
#   'curlist': ['GBP']}]

# %%
state_uk = isle_gb + [wales]
pp(state_uk)
# Out:
# [{'name': 'England',
#   'code': 'england',
#   'official': 'England',
#   'territory': 132932,
#   'population': 57106398,
#   'capital': 'London',
#   'languages': 'English',
#   'world': 'Europe',
#   'currency': 'GBP',
#   'EU': 'no',
#   'Shengen': 'no',
#   'Commonwealth': 'yes',
#   'Realm': 'yes',
#   'NATO': 'yes',
#   'power': 'monarchy',
#   'driveson': 'left',
#   'wiki': 'https://en.wikipedia.org/wiki/England',
#   'langlist': ['English'],
#   'curlist': ['GBP']},
#  {'name': 'Wales',
#   'code': 'wales',
#   'official': 'Wales',
#   'territory': 21218,
#   'population': 3131640,
#   'capital': 'Cardiff',
#   'languages': 'English, Welsh',
#   'world': 'Europe',
#   'currency': 'GBP',
#   'EU': 'no',
#   'Shengen': 'no',
#   'Commonwealth': 'yes',
#   'Realm': 'yes',
#   'NATO': 'yes',
#   'power': 'monarchy',
#   'driveson': 'left',
#   'wiki': 'https://en.wikipedia.org/wiki/Wales',
#   'langlist': ['English', 'Welsh'],
#   'curlist': ['GBP']},
#  {'name': 'Scotland',
#   'code': 'scotland',
#   'official': 'Scotland',
#   'territory': 80231,
#   'population': 5439842,
#   'capital': 'Edinburgh',
#   'languages': 'English, Scots, Scortish Gaelic, British Sign',
#   'world': 'Europe',
#   'currency': 'GBP',
#   'EU': 'no',
#   'Shengen': 'no',
#   'Commonwealth': 'yes',
#   'Realm': 'yes',
#   'NATO': 'yes',
#   'power': 'monarchy',
#   'driveson': 'left',
#   'wiki': 'https://en.wikipedia.org/wiki/Scotland',
#   'langlist': ['English', 'Scots', 'Scortish Gaelic', 'British Sign'],
#   'curlist': ['GBP']},
#  {'name': 'Wales',
#   'code': 'wales',
#   'official': 'Wales',
#   'territory': 21218,
#   'population': 3131640,
#   'capital': 'Cardiff',
#   'languages': 'English, Welsh',
#   'world': 'Europe',
#   'currency': 'GBP',
#   'EU': 'no',
#   'Shengen': 'no',
#   'Commonwealth': 'yes',
#   'Realm': 'yes',
#   'NATO': 'yes',
#   'power': 'monarchy',
#   'driveson': 'left',
#   'wiki': 'https://en.wikipedia.org/wiki/Wales',
#   'langlist': ['English', 'Welsh'],
#   'curlist': ['GBP']}]

# %%
channel = [jersey, guernsey]
pp(channel)
# Out:
# [{'name': 'Jersey',
#   'code': 'bei_jersey',
#   'official': 'Bailiwick of Jersey',
#   'territory': 120,
#   'population': 103267,
#   'capital': 'St.Helier',
#   'languages': 'English, French, Jerriais',
#   'world': 'Europe',
#   'currency': 'GBP, JEP',
#   'EU': 'no',
#   'Shengen': 'no',
#   'Commonwealth': 'yes',
#   'Realm': 'yes',
#   'NATO': 'no',
#   'power': 'monarchy',
#   'driveson': 'left',
#   'wiki': 'https://en.wikipedia.org/wiki/Jersey',
#   'langlist': ['English', 'French', 'Jerriais'],
#   'curlist': ['GBP', 'JEP']},
#  {'name': 'Guernsey',
#   'code': 'bei_guernsey',
#   'official': 'Bailiwick of Guernsey',
#   'territory': 78,
#   'population': 67334,
#   'capital': 'St.Peter Port',
#   'languages': 'English, French, Sercquiais, Auregnais',
#   'world': 'Europe',
#   'currency': 'GBP, GGP',
#   'EU': 'no',
#   'Shengen': 'no',
#   'Commonwealth': 'yes',
#   'Realm': 'yes',
#   'NATO': 'no',
#   'power': 'monarchy',
#   'driveson': 'left',
#   'wiki': 'https://en.wikipedia.org/wiki/Bailiwick_of_Guernsey',
#   'langlist': ['English', 'French', 'Sercquiais', 'Auregnais'],
#   'curlist': ['GBP', 'GGP']}]

# %%
crown_dep = channel + [ioman]
pp(crown_dep)
# Out:
# [{'name': 'Jersey',
#   'code': 'bei_jersey',
#   'official': 'Bailiwick of Jersey',
#   'territory': 120,
#   'population': 103267,
#   'capital': 'St.Helier',
#   'languages': 'English, French, Jerriais',
#   'world': 'Europe',
#   'currency': 'GBP, JEP',
#   'EU': 'no',
#   'Shengen': 'no',
#   'Commonwealth': 'yes',
#   'Realm': 'yes',
#   'NATO': 'no',
#   'power': 'monarchy',
#   'driveson': 'left',
#   'wiki': 'https://en.wikipedia.org/wiki/Jersey',
#   'langlist': ['English', 'French', 'Jerriais'],
#   'curlist': ['GBP', 'JEP']},
#  {'name': 'Guernsey',
#   'code': 'bei_guernsey',
#   'official': 'Bailiwick of Guernsey',
#   'territory': 78,
#   'population': 67334,
#   'capital': 'St.Peter Port',
#   'languages': 'English, French, Sercquiais, Auregnais',
#   'world': 'Europe',
#   'currency': 'GBP, GGP',
#   'EU': 'no',
#   'Shengen': 'no',
#   'Commonwealth': 'yes',
#   'Realm': 'yes',
#   'NATO': 'no',
#   'power': 'monarchy',
#   'driveson': 'left',
#   'wiki': 'https://en.wikipedia.org/wiki/Bailiwick_of_Guernsey',
#   'langlist': ['English', 'French', 'Sercquiais', 'Auregnais'],
#   'curlist': ['GBP', 'GGP']},
#  {'name': 'Isle of Man',
#   'code': 'ioman',
#   'official': 'Isle of Man',
#   'territory': 574,
#   'population': 84069,
#   'capital': 'Douglas',
#   'languages': 'English, Manx',
#   'world': 'Europe',
#   'currency': 'GBP, IMP',
#   'EU': 'no',
#   'Shengen': 'no',
#   'Commonwealth': 'yes',
#   'Realm': 'yes',
#   'NATO': 'no',
#   'power': 'monarchy',
#   'driveson': 'left',
#   'wiki': 'https://en.wikipedia.org/wiki/Isle_of_Man',
#   'langlist': ['English', 'Manx'],
#   'curlist': ['GBP', 'IMP']}]

# %% [markdown]
# **Шаг 5. Готовим и выполняем отчёты с обсчётами по странам и их группам**

# %%
def flatten(lst):
    result = []
    for i in lst:
        if isinstance(i, list):
            result.extend(flatten(i))
        else:
            result.append(i)
    return result

# %%
def about(where, what = 'name'):
    """найти информацию и склеить в список"""
    
    if type(where) == int or type(where) == str or type(where) == None:
        return where

    if type(where) == dict:
        return where[what]

    if type(where) == list:
        res = []
        for e in where:
            res += [about(e, what)]
        res = flatten(res)
        return res

# %%
print(about(ioman))
# Out:
# Isle of Man

# %%
print(about(crown_dep))
print(about(crown_dep, 'official'))
# Out:
# ['Jersey', 'Guernsey', 'Isle of Man']
# ['Bailiwick of Jersey', 'Bailiwick of Guernsey', 'Isle of Man']

# %%
def about_str(where, what='name'):
    """сделать печатаемую строку через запятые"""

    return ", " . join(about(where, what))

# %%
print(about_str(crown_dep))
# Out:
# Jersey, Guernsey, Isle of Man

# %%
def about_sum(where, what='name'):
    """сложить все числа и выдать сумму"""

    return sum(about(where, what))

# %%
print('population =', about_sum(crown_dep, 'population'), 
      ', territory =', about_sum(crown_dep, 'territory'))
# Out:
# population = 254670 , territory = 772

# %%
crdep = [channel, ioman]
pp(crdep)
# Out:
# [[{'name': 'Jersey',
#    'code': 'bei_jersey',
#    'official': 'Bailiwick of Jersey',
#    'territory': 120,
#    'population': 103267,
#    'capital': 'St.Helier',
#    'languages': 'English, French, Jerriais',
#    'world': 'Europe',
#    'currency': 'GBP, JEP',
#    'EU': 'no',
#    'Shengen': 'no',
#    'Commonwealth': 'yes',
#    'Realm': 'yes',
#    'NATO': 'no',
#    'power': 'monarchy',
#    'driveson': 'left',
#    'wiki': 'https://en.wikipedia.org/wiki/Jersey',
#    'langlist': ['English', 'French', 'Jerriais'],
#    'curlist': ['GBP', 'JEP']},
#   {'name': 'Guernsey',
#    'code': 'bei_guernsey',
#    'official': 'Bailiwick of Guernsey',
#    'territory': 78,
#    'population': 67334,
#    'capital': 'St.Peter Port',
#    'languages': 'English, French, Sercquiais, Auregnais',
#    'world': 'Europe',
#    'currency': 'GBP, GGP',
#    'EU': 'no',
#    'Shengen': 'no',
#    'Commonwealth': 'yes',
#    'Realm': 'yes',
#    'NATO': 'no',
#    'power': 'monarchy',
#    'driveson': 'left',
#    'wiki': 'https://en.wikipedia.org/wiki/Bailiwick_of_Guernsey',
#    'langlist': ['English', 'French', 'Sercquiais', 'Auregnais'],
#    'curlist': ['GBP', 'GGP']}],
#  {'name': 'Isle of Man',
#   'code': 'ioman',
#   'official': 'Isle of Man',
#   'territory': 574,
#   'population': 84069,
#   'capital': 'Douglas',
#   'languages': 'English, Manx',
#   'world': 'Europe',
#   'currency': 'GBP, IMP',
#   'EU': 'no',
#   'Shengen': 'no',
#   'Commonwealth': 'yes',
#   'Realm': 'yes',
#   'NATO': 'no',
#   'power': 'monarchy',
#   'driveson': 'left',
#   'wiki': 'https://en.wikipedia.org/wiki/Isle_of_Man',
#   'langlist': ['English', 'Manx'],
#   'curlist': ['GBP', 'IMP']}]

# %%
print(about_str(crdep))
# Out:
# Jersey, Guernsey, Isle of Man

# %%
print('population = ', about_sum(crdep, 'population'), 
      ', territory = ', about_sum(crdep, 'territory'))
# Out:
# population =  254670 , territory =  772
