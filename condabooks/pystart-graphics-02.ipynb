# %% [markdown]
# # Примеры и упражнения по Python3 - уровень с графикой

# %% [markdown]
# Автор-составитель - Михаил Колодин

# %% [markdown]
# Версия 2021-04-17 от 2021-05-14 - 2.1

# %% [markdown]
# Разделы:
# * [Библиотека PIL](#PIL)
# * [Обработка изображений](#images)

# %% [markdown]
# **Библиотека PIL** <a name=PIL></a>
#
# * https://devsday.ru/blog/details/30502
# * https://younglinux.info/tkinter/canvas
# * https://otus.ru/journal/grafika-v-python-tkinter-i-canvas/
# * https://www.youtube.com/watch?v=Yqt1U3Xoask
# * https://pythonru.com/uroki/canvas-risovanie-grafiki-ch-1-tkinter-18
# * https://python-scripts.com/tkinter-canvas-example

# %%
from PIL import Image, ImageDraw
 
# Пустой желтый фон.
im = Image.new('RGB', (500, 300), (219, 193, 27))
draw = ImageDraw.Draw(im)
 
# Рисуем красный эллипс с черной окантовкой.
draw.ellipse((100, 100, 150, 200), fill='red', outline=(0, 0, 0))
 
# Рисуем синий прямоугольник с белой окантовкой.
draw.rectangle((200, 100, 300, 200), fill='blue', outline=(255, 255, 255))
 
# Рисуем розовую линию с шириной в 10 пиксель.
draw.line((350, 200, 450, 100), fill='pink', width=10)
 
#im.show()
im.save('pil-00.jpg', quality=95)

# %%
from PIL import Image
pic = 'pil-00.jpg'
img = Image.open(pic)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x300 at 0x7F045C5D4520>

# %%
# picture 1

from PIL import Image, ImageDraw

# common settings
size = 500
WHITE = (255, 255, 255)
BLACK = (0, 0, 0)

# picture 1
im = Image.new('RGB', (size, size), WHITE)
draw = ImageDraw.Draw(im)

for i in range(0, size, 10):
  draw.line(xy = ((0, 0), (size, i)), fill = 'black', width=1)
  draw.line(xy = ((0, 0), (size-i, size)), fill = 'black', width=1)
 
#im.show()
im.save('pil-01.jpg', quality=95)

# %%
from PIL import Image
pic = 'pil-01.jpg'
img = Image.open(pic)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500 at 0x7F045C036640>

# %%
# picture 2

from PIL import Image, ImageDraw
size = 500
im = Image.new('RGB', (size, size), (255, 255, 255))
draw = ImageDraw.Draw(im)

for i in range(0, size, 10):
    draw.line(xy = ((0, i), (i, size), (size, size-i), (size-i, 0), (0, i)), fill = 'black', width = 1)
    
#im.show()
im.save('pil-02.jpg', quality=95)

# %%
from PIL import Image
pic = 'pil-02.jpg'
img = Image.open(pic)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500 at 0x7F045C5D4490>

# %%
# picture 3

from PIL import Image, ImageDraw
size = 500
im = Image.new('RGB', (size, size), (255, 255, 255))
draw = ImageDraw.Draw(im)

for i in range(0, size, 10):
    draw.line(xy = ( (0, 0), (i, size) ), fill = 'black', width = 1)
    draw.line(xy = ( (0, 0), (size, size-i) ), fill = 'black', width = 1)
    draw.line(xy = ( (size, size), (i, 0) ), fill = 'black', width = 1)
    draw.line(xy = ( (size, size), (0, i) ), fill = 'black', width = 1)
    
#im.show()
im.save('pil-03.jpg', quality=95)

# %%
from PIL import Image
pic = 'pil-03.jpg'
img = Image.open(pic)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500 at 0x7F044EFBD5E0>

# %%
# picture 4

# common settings
size = 500
WHITE = (255, 255, 255)
BLACK = (0, 0, 0)

from PIL import Image, ImageDraw
size = 500
im = Image.new('RGB', (size, size), (255, 255, 255))
draw = ImageDraw.Draw(im)

for i in range(0, size, 10):
    draw.line(xy = ( (0, 0), (i, size) ), fill = 'black', width = 1)
    draw.line(xy = ( (0, 0), (size, size-i) ), fill = 'black', width = 1)
    draw.line(xy = ( (size, size), (i, 0) ), fill = 'black', width = 1)
    draw.line(xy = ( (size, size), (0, i) ), fill = 'black', width = 1)
    
#im.show()
im.save('pil-03.jpg', quality=95)

# picture 4
im = Image.new('RGB', (size, size), WHITE)
draw = ImageDraw.Draw(im)

for i in range(0, size+1, 10):
  draw.line(xy= ((i, 0), (size-i, size)), fill = 'black', width = 1)
  draw.line(xy= ((0, i), (size, size-i)), fill = 'black', width = 1)

#im.show()
im.save('pil-04.jpg', quality=95)

# %%
from PIL import Image
pic = 'pil-04.jpg'
img = Image.open(pic)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500 at 0x7F045C036730>

# %%
# picture 5

from PIL import Image, ImageDraw
import math

# common settings
size = 500
half = size // 2
WHITE = (255, 255, 255)
BLACK = (0, 0, 0)

# picture 1
im = Image.new('RGB', (size, size), WHITE)
draw = ImageDraw.Draw(im)

x = y = half
r = half / 2 - 10

for i in range(0, 360, 30):
    angle = i / 180. * math.pi
    x = half + r * math.sin(angle)
    y = half + r * math.cos(angle)
    draw.ellipse((x-r, y-r, x+r, y+r), fill=None, outline = BLACK)
 
#im.show()
im.save('pil-05.jpg', quality=95)

# %%
from PIL import Image
pic = 'pil-05.jpg'
img = Image.open(pic)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500 at 0x7F044EE8A6D0>

# %%
# picture 6

from PIL import Image, ImageDraw
import math

# common settings
size = 500
half = size // 2
WHITE = (255, 255, 255)
BLACK = (0, 0, 0)

# picture 1
im = Image.new('RGB', (size, size), WHITE)
draw = ImageDraw.Draw(im)

x = y = half

for i in range(0, half-10, 10):
    draw.ellipse((x-i, y-i, x+i, y+i), fill=None, outline = BLACK)
 
#im.show()
im.save('pil-06.jpg', quality=95)

# %%
from PIL import Image
pic = 'pil-06.jpg'
img = Image.open(pic)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500 at 0x7F044EE8A850>

# %%
# picture 7

from PIL import Image, ImageDraw
import math

# common settings
size = 500
half = size // 2
WHITE = (255, 255, 255)
BLACK = (0, 0, 0)

# picture 1
im = Image.new('RGB', (size, size), WHITE)
draw = ImageDraw.Draw(im)

x = y = half

for i in range(0, half-10, 1):
    if i % 3 == 0 or i %5 == 0:
        continue
    draw.ellipse((x-i, y-i, x+i, y+i), fill=None, outline = BLACK)
 
#im.show()
im.save('pil-07.jpg', quality=95)

# %%
from PIL import Image
pic = 'pil-07.jpg'
img = Image.open(pic)
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500 at 0x7F044EE8A400>

# %% [markdown]
# **Обработка изображений** <a name=images></a>

# %% [markdown]
# ***Просто картинки***
#
# чтение, преобразования (изменение размера, цвета), запись в другой файл (другого типа), можно и многое другое

# %%
from PIL import Image
pic = 'pig1.jpg'
img = Image.open(pic)

# %%
img.show()

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=464x310 at 0x7FE42E285CD0>

# %%
print(img.size, img.format)
# Out:
# (464, 310) JPEG

# %%
#img.save(pic + '.png')

# %%
# делаем миниатюру
img.thumbnail((300,300))
img.show()

# %%
gray_img = Image.open(pic).convert('L')
gray_img.show()

# %%
gray_img
# Out:
# <PIL.Image.Image image mode=L size=464x310 at 0x7FDB16E753D0>

# %%
#gray_img.save(pic + '-gray.png','png')
